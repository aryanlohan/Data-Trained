# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv")
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.shape
# Out:
# (4177, 9)

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
print(df['Sex'].value_counts())
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

lab_enc=LabelEncoder()
df2=lab_enc.fit_transform(df['Sex'])
pd.Series(df2)
df['Sex']=df2

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %% [markdown]
# # Target Variable

# %%
df.dtypes
# Out:
# Sex                 int64
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
print(df['Rings'].value_counts())
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: Rings, dtype: int64

# %%
ax = sns.countplot(x="Rings",data=df)

# %% [markdown]
# # Checking Correlation

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# Diameter              0.893162        0.899724      0.905330  0.574660
# Height                0.774972        0.798319      0.817338  0.557467
# Whole weight          0.969405        0.966375      0.955355  0.540390
# Shucked weight        1.000000        0.931961      0.882617  0.420884
# Viscera weight        0.931961        1.000000      0.907656  0.503819
# Shell weight          0.882617        0.907656      1.000000  0.627574
# Rings                 0.420884        0.503819      0.627574  1.000000

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
corr_matrix = df.corr().abs()
corr_matrix["Rings"].sort_values(ascending=False)
# Out:
# Rings             1.000000
# Shell weight      0.627574
# Diameter          0.574660
# Height            0.557467
# Length            0.556720
# Whole weight      0.540390
# Viscera weight    0.503819
# Shucked weight    0.420884
# Sex               0.034627
# Name: Rings, dtype: float64

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber= 1

for column in df:
    if plotnumber<=9:
        ax= plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %% [markdown]
# # Preprocessing

# %%
x = df.drop("Rings",axis=1)
y = df["Rings"]

# %%
x.shape
# Out:
# (4177, 8)

# %%
y.shape
# Out:
# (4177,)

# %% [markdown]
# # Checking Skewness

# %%
x.skew().sort_values(ascending=False)
# Out:
# Height            3.128817
# Shucked weight    0.719098
# Shell weight      0.620927
# Viscera weight    0.591852
# Whole weight      0.530959
# Sex              -0.098155
# Diameter         -0.609198
# Length           -0.639873
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new = power_transform(x)

# %%
x_new
# Out:
# array([[ 1.12707158, -0.68550213, -0.54986033, ..., -0.54098937,
#         -0.69328289, -0.587809  ],
#        [ 1.12707158, -1.39634403, -1.38733299, ..., -1.31166208,
#         -1.33295268, -1.33241968],
#        [-1.30793479, -0.07077438,  0.00853714, ..., -0.36611642,
#         -0.25513514, -0.09826193],
#        ...,
#        [ 1.12707158,  0.59336612,  0.64519089, ...,  0.83813658,
#          1.01560749,  0.59839786],
#        [-1.30793479,  0.85337516,  0.76992788, ...,  0.85873857,
#          0.81518436,  0.51914542],
#        [ 1.12707158,  1.83447784,  1.72628889, ...,  2.10364827,
#          1.61134422,  1.65848824]])

# %%
pd.DataFrame(x_new, columns= x.columns).skew().sort_values(ascending=False)
# Out:
# Viscera weight    0.039780
# Shucked weight    0.027351
# Shell weight      0.023390
# Whole weight     -0.003980
# Diameter         -0.065977
# Length           -0.066669
# Height           -0.115483
# Sex              -0.176442
# dtype: float64

# %%
x = pd.DataFrame(x_new, columns= x.columns)
x.skew().sort_values(ascending=False)
# Out:
# Viscera weight    0.039780
# Shucked weight    0.027351
# Shell weight      0.023390
# Whole weight     -0.003980
# Diameter         -0.065977
# Length           -0.066669
# Height           -0.115483
# Sex              -0.176442
# dtype: float64

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in x:
    if plotnumber<=9:
        ax= plt.subplot(4,3,plotnumber)
        sns.distplot(x[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()

# %%
 x.shape
# Out:
# (4177, 8)

# %%
 y.shape
# Out:
# (4177,)

# %% [markdown]
# # Checking Outliers

# %%
x.boxplot(figsize=[20,8]) 
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))
z.shape

threshold=3
print(np.where(z>3))

x_new=x[(z<3).all(axis=1)]
print("total_dropped_rows",x.shape[0]-x_new.shape[0])

y=y[(z<3).all(axis=1)]
y.shape
# Out:
# (array([ 163,  166,  236,  237,  238,  306,  694,  719,  720,  891, 1174,
#        1209, 1257, 1417, 1428, 1428, 1763, 1987, 2051, 2108, 2161, 2169,
#        2171, 2172, 2334, 2381, 2711, 3190, 3902, 3996]), array([7, 7, 3, 3, 3, 3, 3, 3, 3, 7, 3, 5, 3, 3, 1, 2, 6, 3, 3, 7, 7, 3,
#        3, 3, 1, 3, 3, 3, 3, 3]))
# total_dropped_rows 29
# (4148,)

# %%
x = x_new

# %%
x.shape
# Out:
# (4148, 8)

# %%
y.shape
# Out:
# (4148,)

# %%
plt.figure(figsize=(15,20))
plotnumber = 1

for column in x:
    if plotnumber<=9:
        ax= plt.subplot(3,3,plotnumber)
        sns.stripplot(y,x[column]) 
    plotnumber+=1
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()
x_scaled = scalar.fit_transform(x)

# %%
x_scaled.shape[1]
# Out:
# 8

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['features'] = x.columns
vif
# Out:
#           vif        features
# 0    1.013000             Sex
# 1   36.176677          Length
# 2   34.844985        Diameter
# 3    7.000442          Height
# 4  142.024620    Whole weight
# 5   37.246139  Shucked weight
# 6   22.616913  Viscera weight
# 7   31.278008    Shell weight

# %% [markdown]
# # Training process begins

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    y_pred_train=lr.predict(x_train)
    y_pred=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(y_train,y_pred_train)}")
    print(f"At random state {i},the testing accuracy is:- {r2_score(y_test,y_pred)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 0.5397473338289147
# At random state 0,the testing accuracy is:- 0.5440645858259002
#
#
# At random state 1,the training accuracy is:- 0.5402886922216668
# At random state 1,the testing accuracy is:- 0.5403354385972958
#
#
# At random state 2,the training accuracy is:- 0.5442378294484014
# At random state 2,the testing accuracy is:- 0.5245836987548071
#
#
# At random state 3,the training accuracy is:- 0.5404097390974878
# At random state 3,the testing accuracy is:- 0.540925285159052
#
#
# At random state 4,the training accuracy is:- 0.5427688261834134
# At random state 4,the testing accuracy is:- 0.5296917104347527
#
#
# At random state 5,the training accuracy is:- 0.5366094373238375
# At random state 5,the testing accuracy is:- 0.555321789675334
#
#
# At random state 6,the training accuracy is:- 0.543708901580846
# At random state 6,the testing accuracy is:- 0.5258198019887972
#
#
# At random state 7,the training accuracy is:- 0.5527422295617724
# At random state 7,the testing accuracy is:- 0.49523836273392763
#
#
# At random state 8,the training accuracy is:- 0.5411993242534315
# At random state 8,the testing accuracy is:- 0.5374957643300837
#
#
# At random state 9,the training accuracy is:- 0.5516035384976861
# At random state 9,the testing accuracy is:- 0.49618622794647227
#
#
# At random state 10,the training accuracy is:- 0.5384212394152262
# At random state 10,the testing accuracy is:- 0.5459858537859876
#
#
# At random state 11,the training accuracy is:- 0.5401255503641462
# At random state 11,the testing accuracy is:- 0.5429981613815833
#
#
# At random state 12,the training accuracy is:- 0.5554264114642753
# At random state 12,the testing accuracy is:- 0.4768912340815813
#
#
# At random state 13,the training accuracy is:- 0.5381338296322815
# At random state 13,the testing accuracy is:- 0.5505542172539002
#
#
# At random state 14,the training accuracy is:- 0.5476753462105092
# At random state 14,the testing accuracy is:- 0.5130484557310315
#
#
# At random state 15,the training accuracy is:- 0.5391582088602551
# At random state 15,the testing accuracy is:- 0.5444596735999512
#
#
# At random state 16,the training accuracy is:- 0.5516222157137853
# At random state 16,the testing accuracy is:- 0.4943068835244985
#
#
# At random state 17,the training accuracy is:- 0.5441754721318424
# At random state 17,the testing accuracy is:- 0.5251929095835737
#
#
# At random state 18,the training accuracy is:- 0.536125061161633
# At random state 18,the testing accuracy is:- 0.552471247473443
#
#
# At random state 19,the training accuracy is:- 0.534631015836565
# At random state 19,the testing accuracy is:- 0.5614565922414801
#
#
# At random state 20,the training accuracy is:- 0.549291669694957
# At random state 20,the testing accuracy is:- 0.5052949805444679
#
#
# At random state 21,the training accuracy is:- 0.5443091256409869
# At random state 21,the testing accuracy is:- 0.519740374004763
#
#
# At random state 22,the training accuracy is:- 0.5389608052253965
# At random state 22,the testing accuracy is:- 0.5454267715243681
#
#
# At random state 23,the training accuracy is:- 0.5541680336809924
# At random state 23,the testing accuracy is:- 0.4746215691253164
#
#
# At random state 24,the training accuracy is:- 0.5393287420635857
# At random state 24,the testing accuracy is:- 0.5454907479289084
#
#
# At random state 25,the training accuracy is:- 0.5445568801558234
# At random state 25,the testing accuracy is:- 0.5216630401775861
#
#
# At random state 26,the training accuracy is:- 0.5415576667229584
# At random state 26,the testing accuracy is:- 0.5363777521913207
#
#
# At random state 27,the training accuracy is:- 0.5406879525642452
# At random state 27,the testing accuracy is:- 0.5372870991435881
#
#
# At random state 28,the training accuracy is:- 0.5383617984229995
# At random state 28,the testing accuracy is:- 0.550399488102731
#
#
# At random state 29,the training accuracy is:- 0.5337200699047767
# At random state 29,the testing accuracy is:- 0.5704839293790658
#
#
# At random state 30,the training accuracy is:- 0.543669089009331
# At random state 30,the testing accuracy is:- 0.5285940213826883
#
#
# At random state 31,the training accuracy is:- 0.5393873485281563
# At random state 31,the testing accuracy is:- 0.5453142493168947
#
#
# At random state 32,the training accuracy is:- 0.5383821101704184
# At random state 32,the testing accuracy is:- 0.5472217644244666
#
#
# At random state 33,the training accuracy is:- 0.5415372231514701
# At random state 33,the testing accuracy is:- 0.5350350420338879
#
#
# At random state 34,the training accuracy is:- 0.5402506278063879
# At random state 34,the testing accuracy is:- 0.541974011654566
#
#
# At random state 35,the training accuracy is:- 0.5504164911018816
# At random state 35,the testing accuracy is:- 0.4991988018442288
#
#
# At random state 36,the training accuracy is:- 0.5432925710129177
# At random state 36,the testing accuracy is:- 0.5254779733407277
#
#
# At random state 37,the training accuracy is:- 0.5408291016686575
# At random state 37,the testing accuracy is:- 0.5382689586369087
#
#
# At random state 38,the training accuracy is:- 0.5318983996222024
# At random state 38,the testing accuracy is:- 0.5740418300356422
#
#
# At random state 39,the training accuracy is:- 0.5277906814268716
# At random state 39,the testing accuracy is:- 0.5897270846105389
#
#
# At random state 40,the training accuracy is:- 0.5432740634054609
# At random state 40,the testing accuracy is:- 0.528134694185463
#
#
# At random state 41,the training accuracy is:- 0.5395285640527253
# At random state 41,the testing accuracy is:- 0.5451920508840415
#
#
# At random state 42,the training accuracy is:- 0.5365416328663475
# At random state 42,the testing accuracy is:- 0.5533074967748299
#
#
# At random state 43,the training accuracy is:- 0.5395165591022271
# At random state 43,the testing accuracy is:- 0.5444082360907914
#
#
# At random state 44,the training accuracy is:- 0.5383071884405682
# At random state 44,the testing accuracy is:- 0.5490095021935121
#
#
# At random state 45,the training accuracy is:- 0.5538969282375998
# At random state 45,the testing accuracy is:- 0.4868729642482923
#
#
# At random state 46,the training accuracy is:- 0.5421291306974975
# At random state 46,the testing accuracy is:- 0.5324357586512869
#
#
# At random state 47,the training accuracy is:- 0.5414108292453743
# At random state 47,the testing accuracy is:- 0.5363691180583182
#
#
# At random state 48,the training accuracy is:- 0.5580378370336954
# At random state 48,the testing accuracy is:- 0.4623663357741201
#
#
# At random state 49,the training accuracy is:- 0.5421643398520488
# At random state 49,the testing accuracy is:- 0.5336321242236883
#
#
# At random state 50,the training accuracy is:- 0.5411176726648088
# At random state 50,the testing accuracy is:- 0.5381629858460577
#
#
# At random state 51,the training accuracy is:- 0.5361041305033805
# At random state 51,the testing accuracy is:- 0.5582327445202826
#
#
# At random state 52,the training accuracy is:- 0.5366333118805793
# At random state 52,the testing accuracy is:- 0.5553060033927183
#
#
# At random state 53,the training accuracy is:- 0.5445551029339865
# At random state 53,the testing accuracy is:- 0.5228083522481826
#
#
# At random state 54,the training accuracy is:- 0.5389610317788964
# At random state 54,the testing accuracy is:- 0.5438908626322772
#
#
# At random state 55,the training accuracy is:- 0.5330177217930522
# At random state 55,the testing accuracy is:- 0.5681665459005265
#
#
# At random state 56,the training accuracy is:- 0.5365842173592879
# At random state 56,the testing accuracy is:- 0.5545970908355742
#
#
# At random state 57,the training accuracy is:- 0.5404266351212588
# At random state 57,the testing accuracy is:- 0.5418174445807953
#
#
# At random state 58,the training accuracy is:- 0.5408333757021804
# At random state 58,the testing accuracy is:- 0.5373723131842252
#
#
# At random state 59,the training accuracy is:- 0.5454308088679026
# At random state 59,the testing accuracy is:- 0.521036209935142
#
#
# At random state 60,the training accuracy is:- 0.5402727411132877
# At random state 60,the testing accuracy is:- 0.5405145256664741
#
#
# At random state 61,the training accuracy is:- 0.5358034931643343
# At random state 61,the testing accuracy is:- 0.5551837533941804
#
#
# At random state 62,the training accuracy is:- 0.5392299700501536
# At random state 62,the testing accuracy is:- 0.5452118731948244
#
#
# At random state 63,the training accuracy is:- 0.5450529173357467
# At random state 63,the testing accuracy is:- 0.524037069546019
#
#
# At random state 64,the training accuracy is:- 0.5546768002971534
# At random state 64,the testing accuracy is:- 0.48361810323176624
#
#
# At random state 65,the training accuracy is:- 0.554505454235696
# At random state 65,the testing accuracy is:- 0.480150210530475
#
#
# At random state 66,the training accuracy is:- 0.5400179740133124
# At random state 66,the testing accuracy is:- 0.5422089316011931
#
#
# At random state 67,the training accuracy is:- 0.5469586027624718
# At random state 67,the testing accuracy is:- 0.5129530223512719
#
#
# At random state 68,the training accuracy is:- 0.5445213253087795
# At random state 68,the testing accuracy is:- 0.5207133175209738
#
#
# At random state 69,the training accuracy is:- 0.5463416520124569
# At random state 69,the testing accuracy is:- 0.5162483609787085
#
#
# At random state 70,the training accuracy is:- 0.5455283234695895
# At random state 70,the testing accuracy is:- 0.5204675371760514
#
#
# At random state 71,the training accuracy is:- 0.538793128249512
# At random state 71,the testing accuracy is:- 0.5474569402425203
#
#
# At random state 72,the training accuracy is:- 0.5423457024940048
# At random state 72,the testing accuracy is:- 0.5319045415730972
#
#
# At random state 73,the training accuracy is:- 0.531282868862665
# At random state 73,the testing accuracy is:- 0.5763783932529588
#
#
# At random state 74,the training accuracy is:- 0.5333733714946165
# At random state 74,the testing accuracy is:- 0.5676904428389158
#
#
# At random state 75,the training accuracy is:- 0.5494575829145474
# At random state 75,the testing accuracy is:- 0.5027254472668866
#
#
# At random state 76,the training accuracy is:- 0.5359831947658427
# At random state 76,the testing accuracy is:- 0.5571178771867215
#
#
# At random state 77,the training accuracy is:- 0.5364146181285165
# At random state 77,the testing accuracy is:- 0.5558248920373217
#
#
# At random state 78,the training accuracy is:- 0.540550181528874
# At random state 78,the testing accuracy is:- 0.5376817350743383
#
#
# At random state 79,the training accuracy is:- 0.5370630752236369
# At random state 79,the testing accuracy is:- 0.554720115233344
#
#
# At random state 80,the training accuracy is:- 0.5434863297380155
# At random state 80,the testing accuracy is:- 0.5277695697966569
#
#
# At random state 81,the training accuracy is:- 0.527400638529236
# At random state 81,the testing accuracy is:- 0.5948084705894996
#
#
# At random state 82,the training accuracy is:- 0.5365064371731105
# At random state 82,the testing accuracy is:- 0.5566735696532239
#
#
# At random state 83,the training accuracy is:- 0.5424887394319782
# At random state 83,the testing accuracy is:- 0.5305354311871691
#
#
# At random state 84,the training accuracy is:- 0.5341362864061012
# At random state 84,the testing accuracy is:- 0.5670718323139121
#
#
# At random state 85,the training accuracy is:- 0.5388905355746741
# At random state 85,the testing accuracy is:- 0.5437045045578177
#
#
# At random state 86,the training accuracy is:- 0.537016958245567
# At random state 86,the testing accuracy is:- 0.5496800708419949
#
#
# At random state 87,the training accuracy is:- 0.547631838682052
# At random state 87,the testing accuracy is:- 0.5120911523093536
#
#
# At random state 88,the training accuracy is:- 0.5446358325269399
# At random state 88,the testing accuracy is:- 0.5198293341863728
#
#
# At random state 89,the training accuracy is:- 0.5423756326390659
# At random state 89,the testing accuracy is:- 0.5336125045765465
#
#
# At random state 90,the training accuracy is:- 0.5379145570981525
# At random state 90,the testing accuracy is:- 0.5512687708645694
#
#
# At random state 91,the training accuracy is:- 0.5429082653088
# At random state 91,the testing accuracy is:- 0.5296505777103622
#
#
# At random state 92,the training accuracy is:- 0.5493907475539013
# At random state 92,the testing accuracy is:- 0.5018098476878372
#
#
# At random state 93,the training accuracy is:- 0.5452321425362283
# At random state 93,the testing accuracy is:- 0.5189975020503176
#
#
# At random state 94,the training accuracy is:- 0.5482428673192836
# At random state 94,the testing accuracy is:- 0.5057889353551414
#
#
# At random state 95,the training accuracy is:- 0.544970510929959
# At random state 95,the testing accuracy is:- 0.5213752383434602
#
#
# At random state 96,the training accuracy is:- 0.5330277563484705
# At random state 96,the testing accuracy is:- 0.5694009450614318
#
#
# At random state 97,the training accuracy is:- 0.5425334438592273
# At random state 97,the testing accuracy is:- 0.53238502181024
#
#
# At random state 98,the training accuracy is:- 0.5379668524097095
# At random state 98,the testing accuracy is:- 0.5490293988219774
#
#
# At random state 99,the training accuracy is:- 0.5454186474756748
# At random state 99,the testing accuracy is:- 0.5205677011916731

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20, random_state=10)

# %%
x_train.shape
# Out:
# (3318, 8)

# %%
y_train.shape
# Out:
# (3318,)

# %%
x_test.shape
# Out:
# (830, 8)

# %%
y_test.shape
# Out:
# (830,)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(r2_score(y_test,y_pred)*100)
# Out:
# 54.59858537859876

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
y_pred_dt=dt.predict(x_test)
print("Score", r2_score(y_test,y_pred_dt)*100)
# Out:
# Score 11.73903429197225

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred_rf = rf.predict(x_test)
print("Score", r2_score(y_test,y_pred_rf)*100)
# Out:
# Score 54.03234711788246

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR

svc = SVR()
svc.fit(x_train,y_train)
y_pred_svc = svc.predict(x_test)
print("Score", r2_score(y_test,y_pred_svc)*100)
# Out:
# Score 53.559500069544555

# %% [markdown]
# # Cross Validation

# %%
Train_accuracy=r2_score(y_train,y_pred_train)
Test_accuracy=r2_score(y_test,y_pred)

from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=5)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} cv score is {cv_mean} accuracy score for training is {Train_accuracy*100} accuracy for testing is {Test_accuracy*100}")
print("\n")
# Out:
# At cross fold 2 cv score is 0.4296860927121388 accuracy score for training is -56.36642444232442 accuracy for testing is 54.59858537859876
# At cross fold 3 cv score is 0.4296860927121388 accuracy score for training is -56.36642444232442 accuracy for testing is 54.59858537859876
# At cross fold 4 cv score is 0.4296860927121388 accuracy score for training is -56.36642444232442 accuracy for testing is 54.59858537859876
# At cross fold 5 cv score is 0.4296860927121388 accuracy score for training is -56.36642444232442 accuracy for testing is 54.59858537859876
# At cross fold 6 cv score is 0.4296860927121388 accuracy score for training is -56.36642444232442 accuracy for testing is 54.59858537859876
# At cross fold 7 cv score is 0.4296860927121388 accuracy score for training is -56.36642444232442 accuracy for testing is 54.59858537859876
# At cross fold 8 cv score is 0.4296860927121388 accuracy score for training is -56.36642444232442 accuracy for testing is 54.59858537859876
# At cross fold 9 cv score is 0.4296860927121388 accuracy score for training is -56.36642444232442 accuracy for testing is 54.59858537859876

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Charges',fontsize=14)
plt.ylabel('Predicted Charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters = {'alpha':[.0001, .001, .01, .1, 1, 2, 4, 6, 8, 10], 'random_state': list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.01,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
cv_score=cross_val_score(ls,x_scaled,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 42.93149514197149

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV 
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse','mae'], 'max_features':["auto","sqrt","log2"]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

# %%
rf = RandomForestRegressor(criterion="mae",max_features="log2")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)

# %%
y_pred=rf.predict(x_test)
rfs = r2_score(y_test,y_pred)
print("r2_score:",rfs*100)
rfscore = cross_val_score(rf,x_scaled,y,cv=5)
rfc=rfscore.mean()
print("Cross val score:",rfc*100)

# %%
import joblib
filename = 'abalone.pickle'
pickle.dump(rf, open(filename, 'wb')
